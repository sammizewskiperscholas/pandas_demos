# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0221ENSkillsNetwork899-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # Peer Review Assignment - Data Engineer - Webscraping

# %% [markdown]
# Estimated time needed: **20** minutes

# %% [markdown]
# ## Objectives
#
# In this part you will:
#
# - Use webscraping to get bank information

# %% [markdown]
# For this lab, we are going to be using Python and several Python libraries. Some of these libraries might be installed in your lab environment or in SN Labs. Others may need to be installed by you. The cells below will install these libraries when executed.

# %%
#!mamba install pandas==1.3.3 -y
#!mamba install requests==2.26.0 -y
# !mamba install bs4==4.10.0 -y
# !mamba install html5lib==1.1 -y
# Out:
# 'mamba' is not recognized as an internal or external command,
# operable program or batch file.
# 'mamba' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ## Imports
#
# Import any additional libraries you may need here.

# %%
from bs4 import BeautifulSoup
import html5lib
import requests
import pandas as pd
import wget
from pprint import pp

# %% [markdown]
# ## Extract Data Using Web Scraping

# %% [markdown]
# The wikipedia webpage https://en.wikipedia.org/wiki/List_of_largest_banks provides information about largest banks in the world by various parameters. Scrape the data from the table 'By market capitalization' and store it in a JSON file.

# %% [markdown]
# ### Webpage Contents
#
# Gather the contents of the webpage in text format using the `requests` library and assign it to the variable <code>html_data</code>

# %%
import wget
url= 'https://en.wikipedia.org/wiki/List_of_largest_banks'
wget.download(url)
# Out:
# 'List_of_largest_banks'

# %%
#Write your code here
url = "https://en.wikipedia.org/wiki/List_of_largest_banks"
response = requests.get(url)
html_data = response.content
response
#html_data

# %% [markdown]
# <b>Question 1</b> Print out the output of the following line, and remember it as it will be a quiz question:

# %%
html_data[101:124]
# Out:
# b'guage-in-main-page-head'

# %% [markdown]
# ### Scraping the Data
#
# <b> Question 2</b> Using the contents and `beautiful soup` load the data from the `By market capitalization` table into a `pandas` dataframe. The dataframe should have the bank `Name` and `Market Cap (US$ Billion)` as column names.  Display the first five rows using head.

# %% [markdown]
# Using BeautifulSoup parse the contents of the webpage.

# %%
#Replace the dots below
soup=BeautifulSoup(html_data,"html5lib") #Beautiful soup is class...for loading data
soup
table = soup.find_all('tbody')[2] #find_all method in Beautiful soup
table.contents
# Out:
# [<tr>
#  <th data-sort-type="number">Rank
#  </th>
#  <th>Bank name
#  </th>
#  <th>Market cap<br/>(US$ billion)
#  </th></tr>,
#  '\n',
#  <tr>
#  <td>1
#  </td>
#  <td><span class="flagicon"><a href="/wiki/United_States" title="United States"><img alt="United States" class="thumbborder" data-file-height="650" data-file-width="1235" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/23px-Flag_of_the_United_States.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/35px-Flag_of_the_United_States.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/46px-Flag_of_the_United_States.svg.png 2x" width="23"/></a></span> <a href="/wiki/JPMorgan_Chase" title="JPMorgan Chase">JPMorgan Chase</a>
#  </td>
#  <td>368.78
#  </td></tr>,
#  '\n',
#  <tr>
#  <td>2
#  </td>
# ...

# %% [markdown]
# Load the data from the `By market capitalization` table into a pandas dataframe. The dataframe should have the bank `Name` and `Market Cap (US$ Billion)` as column names. Using the empty dataframe `data` and the given loop extract the necessary data from each row and append it to the empty dataframe.

# %%
data = pd.DataFrame(columns=["Name", "Market Cap (US$ Billion)"]) # empty data frame with given col names

for row in soup.find_all('tbody')[2].find_all('tr'):
    col = row.find_all('td') # table data (td) will be in table rows(tr)
    # print(col)
    if(col != []):
        name = col[1].text.strip() # bring column 1 from table
        marketcap = col[2].text.strip() # bring col 2 from table (table3)
        data = data.append({"Name":name,"Market Cap (US$ Billion)":marketcap}, ignore_index=True)

data

    #Write your code here
# Out:
# C:\Users\Learner_XZHCG217\AppData\Local\Temp\ipykernel_19268\617409972.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name":name,"Market Cap (US$ Billion)":marketcap}, ignore_index=True)
# C:\Users\Learner_XZHCG217\AppData\Local\Temp\ipykernel_19268\617409972.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name":name,"Market Cap (US$ Billion)":marketcap}, ignore_index=True)
# C:\Users\Learner_XZHCG217\AppData\Local\Temp\ipykernel_19268\617409972.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name":name,"Market Cap (US$ Billion)":marketcap}, ignore_index=True)
# ...

# %% [markdown]
# **Question 3** Display the first five rows using the `head` function.

# %%
#Write your code here
data.head()
# Out:
#                                       Name Market Cap (US$ Billion)
# 0                           JPMorgan Chase                   368.78
# 1  Industrial and Commercial Bank of China                   295.65
# 2                          Bank of America                   279.73
# 3                              Wells Fargo                   214.34
# 4                  China Construction Bank                   207.98

# %% [markdown]
# ### Loading the Data
#
# Usually you will Load the `pandas` dataframe created above into a JSON named `bank_market_cap.json` using the `to_json()` function, but this time the data will be sent to another team who will split the data file into two files and inspect it. If you save the data it will interfere with the next part of the assignment.

# %%
#Write your code here
data.to_json("bank_market_cap.json")  #create a json file under ETL

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy, Joseph Santarcangelo and Azim Hirjani

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2022-07-12        | 0.2     | Appalabhaktula Hema | Corrected the code and markdown |
# | 2020-11-25        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
# Copyright © 2020 IBM Corporation.
