# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from lxml import etree

# %% [markdown]
# Make Our Get Reuqest

# %%
url= 'https://en.wikipedia.org/wiki/List_of_largest_banks'
response= requests.get(url)
response
# Out:
# <Response [200]>

# %% [markdown]
# Get content of our response variable

# %%
html_data= response.content
html_data[:50]
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs vector-fe'

# %% [markdown]
# Now we can Create a BeatifulSoup object to parse the html string

# %%
soup= BeautifulSoup(html_data)
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-language-alert-in-sidebar-enabled vector-feature-sticky-header-disabled vector-feature-page-tools-disabled vector-feature-page-tools-pinned-disabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of largest banks - Wikipedia</title>
# ...

# %% [markdown]
# Export into an html file

# %%
with open('list_of_banks.html', 'wb') as file:
    file.write(soup.prettify('utf-8'))

# %%
soup.find('head')
# Out:
# <head>
# <meta charset="utf-8"/>
# <title>List of largest banks - Wikipedia</title>
# ...

# %%
all_links= soup.find_all('a')

# %%
type(all_links)
# Out:
# bs4.element.ResultSet

# %%
table= soup.find('tbody')
table
# Out:
# <tbody><tr>
# <th data-sort-type="number">Rank
# </th>
# <th>Bank name
# </th>
# <th>Total assets<br/>(2021)<br/>(<a class="mw-redirect" href="/wiki/US$" title="US$">US$</a> billion)
# </th></tr>
# <tr>
# <td>1
# </td>
# ...

# %%
type(table)
# Out:
# bs4.element.Tag

# %%
table.find_all('td')
# Out:
# [<td>1
#  </td>,
#  <td><span class="flagicon"><a href="/wiki/China" title="China"><img alt="China" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Flag_of_the_People%27s_Republic_of_China.svg/23px-Flag_of_the_People%27s_Republic_of_China.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Flag_of_the_People%27s_Republic_of_China.svg/35px-Flag_of_the_People%27s_Republic_of_China.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Flag_of_the_People%27s_Republic_of_China.svg/45px-Flag_of_the_People%27s_Republic_of_China.svg.png 2x" width="23"/></a></span> <a href="/wiki/Industrial_and_Commercial_Bank_of_China" title="Industrial and Commercial Bank of China">Industrial and Commercial Bank of China Limited</a>
#  </td>,
#  <td>5,536.53
#  </td>,
#  <td>2
#  </td>,
# ...

# %%
table.find_all('tr')
# Out:
# [<tr>
#  <th data-sort-type="number">Rank
#  </th>
#  <th>Bank name
#  </th>
#  <th>Total assets<br/>(2021)<br/>(<a class="mw-redirect" href="/wiki/US$" title="US$">US$</a> billion)
#  </th></tr>,
#  <tr>
#  <td>1
#  </td>
# ...

# %%
table.parent.parent
# Out:
# <div class="mw-parser-output"><p class="mw-empty-elt">
# </p>
# ...

# %%
table.contents
# Out:
# [<tr>
#  <th data-sort-type="number">Rank
#  </th>
#  <th>Bank name
#  </th>
#  <th>Total assets<br/>(2021)<br/>(<a class="mw-redirect" href="/wiki/US$" title="US$">US$</a> billion)
#  </th></tr>,
#  '\n',
#  <tr>
#  <td>1
#  </td>
# ...

# %%
len(table.contents)
# Out:
# 201

# %%
soup.find_all('a', class_='mw-jump-link')
# Out:
# [<a class="mw-jump-link" href="#bodyContent">Jump to content</a>]

# %%
df_list= pd.read_html(url)
df_list
df= df_list[2]
df
# Out:
#     Rank                                Bank name  Market cap (US$ billion)
# 0      1                           JPMorgan Chase                    368.78
# 1      2  Industrial and Commercial Bank of China                    295.65
# 2      3                          Bank of America                    279.73
# 3      4                              Wells Fargo                    214.34
# 4      5                  China Construction Bank                    207.98
# 5      6               Agricultural Bank of China                    181.49
# 6      7                        HSBC Holdings PLC                    169.47
# 7      8                           Citigroup Inc.                    163.58
# 8      9                            Bank of China                    151.15
# 9     10                     China Merchants Bank                    133.37
# 10    11                     Royal Bank of Canada                    113.80
# ...
